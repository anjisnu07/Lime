# %% [markdown]
# <a href="https://colab.research.google.com/github/prodramp/DeepWorks/blob/main/MLI-XAI/Lime_Original_Explaination.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Model Explainability with LIME (Local Interpretable Model-Agnostic Explanations)**
# - https://github.com/marcotcr/lime

# %%
import os
import keras
from keras.applications import inception_v3 as inc_net
from keras.preprocessing import image
from keras.applications.imagenet_utils import decode_predictions
from skimage.io import imread
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
print('Notebook run using keras:', keras.__version__)
# Out:
# Notebook run using keras: 2.13.1

# %%
inet_model = inc_net.InceptionV3()

# %%
def transform_img_fn(path_list):
    out = []
    for img_path in path_list:
        img = image.load_img(img_path, target_size=(299, 299))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = inc_net.preprocess_input(x)
        out.append(x)
    return np.vstack(out)

# %%
images = transform_img_fn([os.path.join('Image', 'cat_imagenet.jpg')])
# I'm dividing by 2 and adding 0.5 because of how this Inception represents images
plt.imshow(images[0] / 2 + 0.5)
preds = inet_model.predict(images)
for x in decode_predictions(preds)[0]:
    print(x)
# Out:
# 1/1 [==============================] - 2s 2s/step
# ('n02123045', 'tabby', 0.75556093)
# ('n02123159', 'tiger_cat', 0.18292703)
# ('n02124075', 'Egyptian_cat', 0.026877595)
# ('n02127052', 'lynx', 0.00059738103)
# ('n02123394', 'Persian_cat', 0.00048562398)

# %%
# !pip install lime
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: lime in c:\users\royan\appdata\roaming\python\python310\site-packages (0.2.0.1)
# Requirement already satisfied: matplotlib in c:\users\royan\appdata\roaming\python\python310\site-packages (from lime) (3.7.2)
# Requirement already satisfied: numpy in c:\users\royan\appdata\roaming\python\python310\site-packages (from lime) (1.24.3)
# Requirement already satisfied: scipy in c:\users\royan\appdata\roaming\python\python310\site-packages (from lime) (1.11.2)
# Requirement already satisfied: tqdm in c:\users\royan\appdata\roaming\python\python310\site-packages (from lime) (4.66.1)
# Requirement already satisfied: scikit-learn>=0.18 in c:\users\royan\appdata\roaming\python\python310\site-packages (from lime) (1.1.2)
# Requirement already satisfied: scikit-image>=0.12 in c:\users\royan\appdata\roaming\python\python310\site-packages (from lime) (0.23.2)
# Requirement already satisfied: networkx>=2.8 in c:\users\royan\appdata\roaming\python\python310\site-packages (from scikit-image>=0.12->lime) (3.1)
# Requirement already satisfied: pillow>=9.1 in c:\users\royan\appdata\roaming\python\python310\site-packages (from scikit-image>=0.12->lime) (9.5.0)
# Requirement already satisfied: imageio>=2.33 in c:\users\royan\appdata\roaming\python\python310\site-packages (from scikit-image>=0.12->lime) (2.34.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\royan\appdata\roaming\python\python310\site-packages (from scikit-image>=0.12->lime) (2024.5.3)
# Requirement already satisfied: packaging>=21 in c:\users\royan\appdata\roaming\python\python310\site-packages (from scikit-image>=0.12->lime) (23.2)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\royan\appdata\roaming\python\python310\site-packages (from scikit-image>=0.12->lime) (0.4)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\royan\appdata\roaming\python\python310\site-packages (from scikit-learn>=0.18->lime) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\royan\appdata\roaming\python\python310\site-packages (from scikit-learn>=0.18->lime) (3.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\royan\appdata\roaming\python\python310\site-packages (from matplotlib->lime) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\royan\appdata\roaming\python\python310\site-packages (from matplotlib->lime) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\royan\appdata\roaming\python\python310\site-packages (from matplotlib->lime) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\royan\appdata\roaming\python\python310\site-packages (from matplotlib->lime) (1.4.4)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\royan\appdata\roaming\python\python310\site-packages (from matplotlib->lime) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\royan\appdata\roaming\python\python310\site-packages (from matplotlib->lime) (2.8.2)
# Requirement already satisfied: colorama in c:\users\royan\appdata\roaming\python\python310\site-packages (from tqdm->lime) (0.4.4)
# Requirement already satisfied: six in c:\users\royan\appdata\roaming\python\python310\site-packages (from cycler>=0.10->matplotlib->lime) (1.16.0)
# WARNING: Ignoring invalid distribution -angchain-community (c:\users\royan\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\royan\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -angchain-community (c:\users\royan\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\royan\appdata\roaming\python\python310\site-packages)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %load_ext autoreload
# %autoreload 2
import os,sys
try:
    import lime
except:
    sys.path.append(os.path.join('..', '..')) # add the current directory
    import lime
from lime import lime_image

# %%
explainer = lime_image.LimeImageExplainer()

# %%
# %%time
# Hide color is the color for a superpixel turned OFF. Alternatively, if it is NONE, the superpixel will be replaced by the average of its pixels
explanation = explainer.explain_instance(images[0].astype('double'), inet_model.predict, top_labels=5, hide_color=0, num_samples=1000)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# 1/1 [==============================] - 1s 699ms/step
# 1/1 [==============================] - 1s 631ms/step
# 1/1 [==============================] - 1s 657ms/step
# 1/1 [==============================] - 1s 667ms/step
# 1/1 [==============================] - 1s 693ms/step
# 1/1 [==============================] - 1s 689ms/step
# 1/1 [==============================] - 1s 728ms/step
# 1/1 [==============================] - 1s 679ms/step
# 1/1 [==============================] - 1s 667ms/step
# 1/1 [==============================] - 1s 681ms/step
# 1/1 [==============================] - 1s 720ms/step
# 1/1 [==============================] - 1s 637ms/step
# 1/1 [==============================] - 1s 692ms/step
# 1/1 [==============================] - 1s 685ms/step
# 1/1 [==============================] - 1s 653ms/step
# 1/1 [==============================] - 1s 730ms/step
# 1/1 [==============================] - 1s 701ms/step
# 1/1 [==============================] - 1s 645ms/step
# 1/1 [==============================] - 1s 662ms/step
# 1/1 [==============================] - 1s 707ms/step
# 1/1 [==============================] - 1s 647ms/step
# 1/1 [==============================] - 1s 673ms/step
# 1/1 [==============================] - 1s 680ms/step
# 1/1 [==============================] - 1s 646ms/step
# 1/1 [==============================] - 1s 663ms/step
# 1/1 [==============================] - 1s 668ms/step
# 1/1 [==============================] - 1s 686ms/step
# 1/1 [==============================] - 1s 679ms/step
# 1/1 [==============================] - 1s 698ms/step
# 1/1 [==============================] - 1s 720ms/step
# 1/1 [==============================] - 1s 705ms/step
# 1/1 [==============================] - 1s 692ms/step
# 1/1 [==============================] - 1s 691ms/step
# 1/1 [==============================] - 1s 685ms/step
# 1/1 [==============================] - 1s 702ms/step
# 1/1 [==============================] - 1s 662ms/step
# 1/1 [==============================] - 1s 682ms/step
# 1/1 [==============================] - 1s 671ms/step
# 1/1 [==============================] - 1s 762ms/step
# 1/1 [==============================] - 1s 655ms/step
# 1/1 [==============================] - 1s 669ms/step
# 1/1 [==============================] - 1s 686ms/step
# 1/1 [==============================] - 1s 684ms/step
# 1/1 [==============================] - 1s 659ms/step
# 1/1 [==============================] - 1s 727ms/step
# 1/1 [==============================] - 1s 682ms/step
# 1/1 [==============================] - 1s 650ms/step
# 1/1 [==============================] - 1s 719ms/step
# 1/1 [==============================] - 1s 707ms/step
# 1/1 [==============================] - 1s 751ms/step
# 1/1 [==============================] - 1s 682ms/step
# 1/1 [==============================] - 1s 659ms/step
# 1/1 [==============================] - 1s 679ms/step
# 1/1 [==============================] - 1s 650ms/step
# 1/1 [==============================] - 1s 640ms/step
# 1/1 [==============================] - 1s 675ms/step
# 1/1 [==============================] - 1s 673ms/step
# 1/1 [==============================] - 1s 650ms/step
# 1/1 [==============================] - 1s 631ms/step
# 1/1 [==============================] - 1s 661ms/step
# 1/1 [==============================] - 1s 646ms/step
# 1/1 [==============================] - 1s 653ms/step
# 1/1 [==============================] - 1s 661ms/step
# 1/1 [==============================] - 1s 646ms/step
# 1/1 [==============================] - 1s 647ms/step
# 1/1 [==============================] - 1s 617ms/step
# 1/1 [==============================] - 1s 638ms/step
# 1/1 [==============================] - 1s 700ms/step
# 1/1 [==============================] - 1s 625ms/step
# 1/1 [==============================] - 1s 623ms/step
# 1/1 [==============================] - 1s 675ms/step
# 1/1 [==============================] - 1s 654ms/step
# 1/1 [==============================] - 1s 661ms/step
# 1/1 [==============================] - 1s 687ms/step
# 1/1 [==============================] - 1s 644ms/step
# 1/1 [==============================] - 1s 655ms/step
# 1/1 [==============================] - 1s 639ms/step
# 1/1 [==============================] - 1s 643ms/step
# 1/1 [==============================] - 1s 671ms/step
# 1/1 [==============================] - 1s 622ms/step
# 1/1 [==============================] - 1s 636ms/step
# 1/1 [==============================] - 1s 667ms/step
# 1/1 [==============================] - 1s 617ms/step
# 1/1 [==============================] - 1s 637ms/step
# 1/1 [==============================] - 1s 709ms/step
# 1/1 [==============================] - 1s 667ms/step
# 1/1 [==============================] - 1s 787ms/step
# 1/1 [==============================] - 1s 705ms/step
# 1/1 [==============================] - 1s 632ms/step
# 1/1 [==============================] - 1s 650ms/step
# 1/1 [==============================] - 1s 629ms/step
# 1/1 [==============================] - 1s 666ms/step
# 1/1 [==============================] - 1s 639ms/step
# 1/1 [==============================] - 1s 642ms/step
# 1/1 [==============================] - 1s 651ms/step
# 1/1 [==============================] - 1s 668ms/step
# 1/1 [==============================] - 1s 671ms/step
# 1/1 [==============================] - 1s 620ms/step
# 1/1 [==============================] - 1s 638ms/step
# 1/1 [==============================] - 1s 612ms/step
# CPU times: total: 3min 20s
# Wall time: 1min 19s

# %%
explanation

# %%
from skimage.segmentation import mark_boundaries

# %% [markdown]
# # **Superpixel for the top most Prediction**

# %%
temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=True, num_features=5, hide_rest=True)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))

# %%
images = transform_img_fn([os.path.join('Image', 'output.png')])
# I'm dividing by 2 and adding 0.5 because of how this Inception represents images
plt.imshow(images[0] / 2 + 0.5)
preds = inet_model.predict(images)
for x in decode_predictions(preds)[0]:
    print(x)
# Out:
# 1/1 [==============================] - 0s 345ms/step
# ('n06359193', 'web_site', 0.12121698)
# ('n06596364', 'comic_book', 0.07035671)
# ('n07248320', 'book_jacket', 0.057761703)
# ('n03598930', 'jigsaw_puzzle', 0.046887234)
# ('n03729826', 'matchstick', 0.029089147)

# %%
temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=True, num_features=5, hide_rest=False)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))

# %% [markdown]
# # **Visualizing 'pros and cons'**
# - pros in green
# - cons in red

# %%
temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=False, num_features=10, hide_rest=False)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))

# %% [markdown]
# ## **pros and cons**
#  - With weight at least 0.1

# %%
temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=False, num_features=1000, hide_rest=False, min_weight=0.1)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))

# %% [markdown]
# ## **Explaination Heatmap plot with weights**
# - Colorbar shows the values of the weights.

# %%
#Select the same class explained on the figures above.
ind =  explanation.top_labels[0]

#Map each explanation weight to the corresponding superpixel
dict_heatmap = dict(explanation.local_exp[ind])
heatmap = np.vectorize(dict_heatmap.get)(explanation.segments) 

#Plot. The visualization makes more sense if a symmetrical colorbar is used.
plt.imshow(heatmap, cmap = 'RdBu', vmin  = -heatmap.max(), vmax = heatmap.max())
plt.colorbar()

# %% [markdown]
# # **Second Prediction in the list**

# %% [markdown]
# ## **Superpixel for the second most Prediction**

# %%
temp, mask = explanation.get_image_and_mask(explanation.top_labels[1], positive_only=True, num_features=5, hide_rest=True)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))

# %% [markdown]
# ## **Rest of the image from the second prediction**

# %%
temp, mask = explanation.get_image_and_mask(explanation.top_labels[1], positive_only=True, num_features=5, hide_rest=False)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))

# %% [markdown]
# ## **Visualizing 'pros and cons'**
# - pros in green
# - cons in red

# %%
temp, mask = explanation.get_image_and_mask(explanation.top_labels[1], positive_only=False, num_features=10, hide_rest=False)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))

# %% [markdown]
# ## **pros and cons**
#  - that have weight at least 0.1

# %%
temp, mask = explanation.get_image_and_mask(explanation.top_labels[1], positive_only=False, num_features=1000, hide_rest=False, min_weight=0.1)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))

# %% [markdown]
# ## **Explanation Heatmap plot with weights**
# - Colorbar shows the values of the weights.

# %%
#Select the same class explained on the figures above.
ind =  explanation.top_labels[1]

#Map each explanation weight to the corresponding superpixel
dict_heatmap = dict(explanation.local_exp[ind])
heatmap = np.vectorize(dict_heatmap.get)(explanation.segments) 

#Plot. The visualization makes more sense if a symmetrical colorbar is used.
plt.imshow(heatmap, cmap = 'RdBu', vmin  = -heatmap.max(), vmax = heatmap.max())
plt.colorbar()
